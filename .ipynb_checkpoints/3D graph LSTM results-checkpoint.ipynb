# %%
#jupyter notebook for drawing 3D trajectory

# %%
# load numpy array from npy file
from numpy import load

from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis  
# load array
z = load('saved test&predict results/z_pred.npy')
x = load('saved test&predict results/x_pred.npy')
y = load('saved test&predict results/y_pred.npy')

z_test = load('saved test&predict results/z_test.npy')
x_test = load('saved test&predict results/x_test.npy')
y_test = load('saved test&predict results/y_test.npy')

 
# plotting
ax.plot3D(x_test, y_test, z_test, 'red')
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot LSTM')
plt.show()
#red for truth 
#green for prediction

# %%
# load numpy array from npy file
from numpy import load

from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis  
# load array
z_test = load('z_test.npy')
x_test = load('x_test.npy')
y_test = load('y_test.npy')

 
# plotting
ax.plot3D(x_test, y_test, z_test, 'red')
ax.set_title('3D line plot LSTM')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 15>()
#      11 ax = plt.axes(projection ='3d')
#      13 # defining all 3 axis
#      14 # load array
# ---> 15 z_test = load('z_test.npy')
#      16 x_test = load('x_test.npy')
#      17 y_test = load('y_test.npy')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'z_test.npy'
